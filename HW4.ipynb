# %%
from HW4 import HW4

problem = HW4('HW4.yml')

# %%
problem.run(plot_freq=1)
problem.get_solution()
# Out:
# array([ 1091.86614926,  1091.86614924,  1091.8661492 , ...,   500.0006673 ,
#          500.00040038,   500.00013346])

# %%
# %matplotlib inline
problem.plot()

# %%
problem.plot_BHP()
