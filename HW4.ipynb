# %%
from HW4 import HW4

problem = HW4('HW4.in')

# %%
problem.run(plot_freq=1)
problem.get_solution()
# Out:
# array([ 505.12406673,  505.1240667 ,  505.12406663, ...,  500.00100611,
#         500.00060366,  500.00020122])

# %%
# %matplotlib inline
problem.plot()

# %%
problem.plot_BHP()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-4d2dae982646> in <module>()
# ----> 1 problem.plot_BHP()
#
# /Users/john/Documents/PGE323M-ReservoirSimulation/assignments/HW4/HW4.py in plot_BHP(self, x_unit, y_unit)
#     432         #Raise exception if trying to plot and there are no rate wells defined
#     433         if self.rate_well_grids is None:
# --> 434             raise ValueError("No constant rate wells are defined.")
#     435
#     436         #Pointer reassignments for convenience
#
# ValueError: No constant rate wells are defined.
