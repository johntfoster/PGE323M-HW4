# %%
from HW4 import HW4

problem = HW4('HW4.in')

# %%
problem.run(plot_freq=1)
problem.get_solution()
# Out:
# array([ 1149.86925136,  1135.51278781,  1127.05827502,  1120.39778115,
#         1112.61929309,  1107.48218361,  1103.17080066,  1079.10545424,
#         1055.42224373,  1050.47578123,  1036.67965414,  1023.59991107,
#         1019.43074445,  1003.11048678,   986.701906  ,   978.92582282,
#          968.89419964,   960.39955506,   954.14614211,   949.50684675,
#          941.53439378,   929.13149093,   892.0272913 ,   856.41827578,
#          845.85373599,   813.58632198,   778.95050024,   742.80862012,
#          688.17135447,   656.61788047,   648.2174381 ,   629.82227778,
#          611.72263247,   607.44134717,   603.35504709,   599.55356409,
#          593.16713585,   581.35252784,   560.70001333,   545.04367196,
#          527.7999653 ,   509.72296888,   501.45304131,   501.44131601,
#          501.43366944,   501.42441784,   501.4118799 ,   501.401804  ,
#          501.39493942,   501.36731366,   501.33968274,   501.33195885,
# ...

# %% [markdown]
# I can type a **fancy** equation
#
# $$
# \sigma = \frac{P}{A}
# $$

# %%
# %matplotlib inline
problem.plot()

# %%
problem.plot_BHP()
